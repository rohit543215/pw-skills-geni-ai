# %% [markdown]
# # Staistics part 2

# %% [markdown]
# ## 1. What is hypothesis testing in statistics?

# %% [markdown]
# ### hypothesis testing in statistics is a method used to make decisions or inferences about a population based on a sample data. it helps you determine whether there is enough evidence to support a specific claim or belief about a population parameter.

# %% [markdown]
# ## 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?

# %% [markdown]
# ### 📌 Null Hypothesis (H₀):
# - The null hypothesis is a statement that there is no effect, no difference,     or no relationship in the population.
# - It is the default assumption we test against.
# - We assume the null hypothesis is true unless we have strong evidence to      reject it.
# - 🔸Example:
# - H₀: the average height of students= 170cm (μ = 170)
# - H₀: A new drug has no effect on blood pressure.

# %% [markdown]
# ### 📌 Alternative Hypothesis (H₁ or Ha):
# - The alternative hypothesis is what you want to prove or support.
# - it suggests that there is an effect, a difference, or a relationship.
# - if the evidence is dtrong enough to reject H₀, we accept H₁.
# - 🔸 Example:
# - H₁: The average height of students ≠ 170 cm (μ ≠ 170)
# - H₁: The new drug does affect blood pressure.

# %% [markdown]
# ## 3.What is the significance level in hypothesis testing, and why is it important?

# %% [markdown]
# ### 📌 Definition:
# The significance level (denoted by α, alpha) is the threshold for deciding whether a result is statistically significant.
# It represents the maximum probability of making a Type I error — that is, rejecting the null hypothesis (H₀) when it is actually true.

# %% [markdown]
# ### 🧠 Why Is It Important?
# 🧠 Why Is It Important
# - 1.Sets the standard for decision-making:
#    - It helps you decide whether your test result is due to random chance or   real effect.
#   -You compare the p-value to α:
#     - If p-value < α → reject H₀ (significant result).
#     - If p-value ≥ α → fail to reject H₀ (not significant).
# - 2.Controls risk:
#   - By choosing α, you control how willing you are to make a false positive   (Type I error).
#   - For example, with α = 0.05, you're accepting a 5% chance of wrongly  rejecting a true null hypothesis.
# - 3.Balancing errors:
#   - Lower α reduces the chance of a Type I error but increases the chance of a Type II error (failing to detect a real effect).

# %% [markdown]
# ## 4.What does a p-value represent in hypothesis testing.?

# %% [markdown]
# ### 📌 Definition:
# The p-value is the probability of observing the sample results (or something more extreme) assuming the null hypothesis (H₀) is true.

# %% [markdown]
# ### 💡 In Simple Words:
# - It answers the question:
#   "If there really is no effect (H₀ is true), how likely is it that we would see these results?"
# - A small p-value means that the observed data is unlikely under H₀, so we have evidence against H₀.

# %% [markdown]
# ## 5. How do you interpret the p-value in hypothesis testing?

# %% [markdown]
# ### 🎯 In Simple Terms:
# - Small p-value (e.g., 0.01):
#   There’s only a 1% chance that the observed results are due to random chance if H₀ is true → strong reason to reject H₀.
# - Large p-value (e.g., 0.6):
#  There's a 60% chance the results are just due to randomness → not enough evidence to reject H₀.

# %% [markdown]
# ## 6.What are type-1 and type-2 errors in hypothesis testing?

# %% [markdown]
# ### 📌 1. Type I Error (False Positive):
#      - Definition: Rejecting the null hypothesis (H₀) when it is actually   true.
#      - In Simple Terms: You think there is an effect, but there isn’t.

# %% [markdown]
# ### 📌 2. Type II Error (False Negative):
# - Definition: Failing to reject the null hypothesis (H₀) when the alternative hypothesis (H₁) is actually true.
# - In Simple Terms: You think there’s no effect, but there actually is.

# %% [markdown]
# ## 7.What is the difference between a one-tailed and two-tailed test in hypothesis testing?

# %% [markdown]
# ### 📌 1. One-Tailed Test:
# - Used when you are testing for an effect in one specific direction.
# - You are only interested in either increase or decrease, not both.
#
# 🔸 Example:
# - You want to test if a new teaching method improves test scores (not just changes them).
#
# - H₀: μ ≤ 70
# - H₁: μ > 70 (one-tailed to the right)

# %% [markdown]
# ### 📌 2. Two-Tailed Test:
# - Used when you are testing for an effect in either direction.
# - You care about any difference, not whether it's specifically higher or lower.
#
# 🔸 Example:
# You want to test if a machine's output differs from the standard 100g (could be more or less).
# - H₀: μ = 100
# - H₁: μ ≠ 100

# %% [markdown]
# ## 8.What is the Z-test, and when is it used in hypothesis testing?

# %% [markdown]
# ### 📌 Z-test Definition:
# A Z-test is a statistical test used to determine whether there is a significant difference between sample and population means, or between two sample means, when the population standard deviation is known and the data is normally distributed (or sample size is large, typically n ≥ 30).
#
# It uses the Z-distribution (standard normal distribution) for calculation.

# %% [markdown]
# ### formula z=X-μ/(σ/(n)^1/2)

# %% [markdown]
# ## 9.How do you calculate the Z-score, and what does it represent in hypothesis testing?

# %% [markdown]
# ### 📌 What is a Z-score?
# A Z-score tells you how many standard deviations a data point (or sample mean) is from the population mean.
#
# In hypothesis testing, it helps you decide whether to reject the null hypothesis (H₀) by comparing the Z-score to critical values from the standard normal distribution.
#
# 📌 What It Represents:
# - A Z-score of 0 → Sample mean = population mean (no difference)
# - A positive Z-score → Sample mean is above the population mean
# - A negative Z-score → Sample mean is below the population mean
# - The larger the absolute value of Z, the more extreme the result

# %% [markdown]
# ## 10.What is the T-distribution,and when should it be used instead of the normal distribution?

# %% [markdown]
# ### 📌 What is the T-distribution?
# The T-distribution (Student's t-distribution) is a probability distribution similar to the normal distribution but with heavier (thicker) tails.
#
# These heavier tails account for the extra uncertainty that comes when:
# - Sample size is small
# - Population standard deviation (σ) is unknown

# %% [markdown]
# ### 🧪 When to Use the T-distribution Instead of the Normal Distribution:
#
# | ✅ Condition                                              | ✅ Why t-distribution is Better          |
# | --------------------------------------------------------   | --------------------------------------- |
# | The **sample size is small** (n < 30)                      | The sample mean has more variability    |
# | The **population standard deviation** (σ) is **unknown**   | You have to estimate σ using the sample |
# | You are working with **mean comparisons**                  | Common in T-tests (1-sample, 2-sample)  |

# %% [markdown]
# ## 11.What is the difference between a Z-test and T-test?

# %% [markdown]
# | Feature         | **Normal Distribution (Z)**    | **T-distribution (T)**           |
# | --------------- | ------------------------------ | -------------------------------- |
# | Shape           | Bell-shaped, narrower tails    | Bell-shaped, **wider** tails     |
# | Use when        | σ is **known**, n is **large** | σ is **unknown**, n is **small** |
# | Based on        | Standard normal curve          | Degrees of freedom (df = n – 1)  |
# | Critical values | From **Z-table**               | From **T-table**                 |

# %% [markdown]
# ## 12.What is the T-test, and how is it used in hypothesis testing?

# %% [markdown]
# ### 📌 What is the T-test?
# A T-test is a statistical test used to compare means and determine whether the difference between them is statistically significant, especially when the sample size is small and the population standard deviation is unknown.
#
# It uses the T-distribution to calculate the test statistic (t-score).

# %% [markdown]
# 🎯 When to Use a T-test:
# Use a T-test when:
#
# You want to test mean differences
#
# The sample size is small (n < 30)
#
# The population standard deviation (σ) is unknown

# %% [markdown]
# ## 13.What is the relationship between Z-test and T-test in hypothesis testing?

# %% [markdown]
# | Feature               | **Z-test**                                         | **T-test**                                                     |
# | --------------------- | -------------------------------------------------- | -------------------------------------------------------------- |
# | **Used when**         | Population standard deviation (**σ**) is **known** | σ is **unknown**, and we use **sample standard deviation (s)** |
# | **Sample size**       | Typically **large** (n ≥ 30)                       | **Small** (n < 30), but also works for large n                 |
# | **Distribution used** | **Standard normal distribution (Z-distribution)**  | **T-distribution** (heavier tails)                             |
# | **Formula structure** | Same structure as T-test                           | Same as Z-test but uses **s instead of σ**                     |
# | **As n increases**    | Z remains the same                                 | **T approaches Z-distribution** as n → ∞                       |

# %% [markdown]
# ## 14.What is a confidence interval, and how is it used to interpret statistical results?

# %% [markdown]
# ### 📌 Definition:
# A confidence interval (CI) is a range of values that is likely to contain the true population parameter (like the mean or proportion) with a certain level of confidence.
#
# It gives an estimate along with a measure of uncertainty.

# %% [markdown]
# ### 📌 How It's Used in Statistics:
# To estimate population parameters (e.g., average height, sales, conversion rates)
#
# To show precision: narrower CI = more precise; wider CI = more uncertainty
#
# In hypothesis testing:
# If a hypothesized value (like μ₀) lies outside the CI, it is likely to be rejected.

# %% [markdown]
# ## 15.What is the margin of error, and how does it affect the cnfidence interval?

# %% [markdown]
# ### 📌 Definition:
# The margin of error (MoE) is the maximum expected difference between the sample estimate (like sample mean or proportion) and the true population value.
#
# It tells you how much uncertainty is in your estimate.

# %% [markdown]
# | Factor                                     | Effect on MoE               |
# | ------------------------------------------ | --------------------------- |
# | 🔺 **Higher confidence level (e.g., 99%)** | Increases MoE (wider CI)    |
# | 🔻 **Larger sample size (n)**              | Decreases MoE (narrower CI) |
# | 🔺 **Higher variability (σ or s)**         | Increases MoE               |

# %% [markdown]
# ## 16.How is bayes' Theorem used in statistics, and when is it used?

# %% [markdown]
# ### 📌 What Is Bayes’ Theorem?
# Bayes' Theorem is a way of updating probabilities based on new evidence.
# It connects prior knowledge with new data to calculate a posterior probability.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
img = mpimg.imread('Screenshot 2025-06-20 183547.png')  # Replace with your image path
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title("Displayed Image")
plt.show()

# %% [markdown]
# | Use Case                   | Explanation                                                                           |
# | -------------------------- | ------------------------------------------------------------------------------------- |
# | 🔍 **Medical testing**     | To find the chance a patient has a disease given a positive test result               |
# | 📈 **Spam filtering**      | To update whether an email is spam based on the words in it                           |
# | 🎲 **Diagnostic problems** | To update the probability of a hypothesis after seeing test outcomes                  |
# | 🧠 **Bayesian statistics** | Involves using Bayes’ theorem to calculate **posterior distributions** for parameters |

# %% [markdown]
# ## 17.What is the Chi-square distribution, and when is it used?

# %% [markdown]
# ### 📌 Definition:
# The Chi-square (χ²) distribution is a probability distribution used mainly for testing relationships between categorical variables and for evaluating goodness of fit.
#
# It is right-skewed and only takes non-negative values.

# %% [markdown]
# | Use Case                    | Description                                                                  |
# | --------------------------- | ---------------------------------------------------------------------------- |
# | 📊 **Goodness-of-Fit Test** | Checks if a sample matches a theoretical distribution                        |
# | 📈 **Test of Independence** | Checks if two categorical variables are related (e.g., gender vs preference) |
# | 📐 **Variance Testing**     | In some advanced tests (like comparing sample vs population variance)        |

# %% [markdown]
# ## 18.What is the chi-square goodness of fit-test, and how is it applied?

# %% [markdown]
# 📌 Definition:
# The Chi-square goodness of fit test is a statistical test used to determine whether a sample data set fits a specific theoretical distribution (like uniform, binomial, etc.).
#
# It compares the observed frequencies with the expected frequencies.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
img = mpimg.imread('Screenshot 2025-06-20 184147.png')  # Ensure the image is in the same directory
plt.figure(figsize=(8, 6))  # Optional: adjust display size
plt.imshow(img)
plt.axis('off')  # Hide x and y axes
plt.title("Displayed Image")
plt.show()

# %% [markdown]
# ## 19.What is the f-distribution, and when is it used in hypothesis testing?

# %% [markdown]
# ### 📌 What is the F-distribution?
# The F-distribution is a right-skewed probability distribution that arises when comparing two variances.
# It is used in hypothesis tests involving variance ratios, such as in ANOVA and F-tests.
#
# It is defined as the ratio of two independent chi-square variables divided by their degrees of freedom:

# %% [markdown]
# | 📘 Use Case                         | Description                                                            |
# | ----------------------------------- | ---------------------------------------------------------------------- |
# | 🔍 **ANOVA (Analysis of Variance)** | To compare **means** of more than two groups                           |
# | 🔁 **F-test for variances**         | To compare **two population variances**                                |
# | 📈 **Regression analysis**          | To test **overall model significance** (whether predictors are useful) |

# %% [markdown]
# ## 20.What is an ANOVA test, and what are its assumptions?

# %% [markdown]
# ### 📌 Definition of ANOVA:
# ANOVA (Analysis of Variance) is a statistical test used to compare the means of three or more groups to determine if at least one group mean is significantly different from the others.
#
# It uses the F-distribution to test the null hypothesis that all group means are equal.

# %% [markdown]
# | Assumption                                       | Explanation                                                     |
# | ------------------------------------------------ | --------------------------------------------------------------- |
# | ✅ **Independence**                               | Samples are independent of each other                           |
# | ✅ **Normality**                                  | Data in each group should be approximately normally distributed |
# | ✅ **Homogeneity of variance** (Homoscedasticity) | All groups should have similar variances                        |

# %% [markdown]
# ## 21.What are the different types of ANOVA tests?

# %% [markdown]
# | Type of ANOVA               | Use Case                                                          |
# | --------------------------- | ----------------------------------------------------------------- |
# | **One-Way ANOVA**           | Compare means of 3+ independent groups based on **one factor**    |
# | **Two-Way ANOVA**           | Compare means based on **two factors** (e.g., gender × treatment) |
# | **Repeated Measures ANOVA** | Used when **same subjects** are tested multiple times             |

# %% [markdown]
# ## 22.What is the F-test,and how does it relate to hypothesis testing?

# %% [markdown]
# ### 📌 Definition of the F-test:
# The F-test is a statistical test used to compare two variances or to test the overall significance of a model (especially in ANOVA or regression).
# It is based on the F-distribution, which is a ratio of two variances.

# %% [markdown]
# ### 🧪 Formula for F-test:

# %% [markdown]
# ### F=Variance1/Variance2
# 🧠 How It Relates to Hypothesis Testing:
# ✅ Hypotheses for F-test (for variances):
# H₀ (null):
# 𝜎
# 1
# 2
# =
# 𝜎
# 2
# 2
# σ
# 1
# 2
# ​
#  =σ
# 2
# 2
# ​
#   (variances are equal)
#
# H₁ (alternative):
# 𝜎
# 1
# 2
# ≠
# 𝜎
# 2
# 2
# σ
# 1
# 2
# ​
#
# 
# =σ
# 2
# 2
# ​
#   (variances are different)

# %% [markdown]
# # Practical Questions

# %% [markdown]
# ## 1. performing a Z-test to compare a sample mean with a known population mean:

# %%
from scipy.stats import norm
import numpy as np

# Sample data
data = [104, 102, 98, 101, 99, 105, 100, 103, 97, 106]
sample_mean = np.mean(data)
population_mean = 100
population_std = 5
n = len(data)

# Z-test
z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
p = 2 * (1 - norm.cdf(abs(z)))

print("Z-score:", z)
print("P-value:", p)
# Out:
# Z-score: 0.9486832980505139
# P-value: 0.3427817111479112

# %% [markdown]
# ## 2. Simulate random data to perform hypothesis testing and calculate the corressponding p-value using python?

# %%
import numpy as np
from scipy import stats

# Step 1: Simulate two groups
np.random.seed(1)
group_A = np.random.normal(loc=50, scale=10, size=30)
group_B = np.random.normal(loc=55, scale=10, size=30)

# Step 2: Perform two-sample t-test
t_stat, p_val = stats.ttest_ind(group_A, group_B)

# Step 3: Print results
print("Group A Mean:", np.mean(group_A))
print("Group B Mean:", np.mean(group_B))
print("T-statistic:", t_stat)
print("P-value:", p_val)
# Out:
# Group A Mean: 49.40061089344376
# Group B Mean: 55.765675804941324
# T-statistic: -2.62328666994493
# P-value: 0.011109247864492152

# %% [markdown]
# ## 3.implement a one-sample Z-test using python to compare the sample mean with the population.

# %%
import numpy as np
from scipy.stats import norm

# Sample data
data = [104, 102, 98, 101, 99, 105, 100, 103, 97, 106]
sample_mean = np.mean(data)
population_mean = 100
population_std = 5
n = len(data)

# Z-test
z = (sample_mean - population_mean) / (population_std / np.sqrt(n))
p = 2 * (1 - norm.cdf(abs(z)))  # two-tailed test

print("Z-score:", z)
print("P-value:", p)
# Out:
# Z-score: 0.9486832980505139
# P-value: 0.3427817111479112

# %% [markdown]
# ## 4.Perform a two-tailed Z-test using python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
data = [104, 102, 98, 101, 99, 105, 100, 103, 97, 106]
mean = np.mean(data)
n = len(data)
pop_mean = 100
pop_std = 5

# Z-test
z = (mean - pop_mean) / (pop_std / np.sqrt(n))
p = 2 * (1 - norm.cdf(abs(z)))
print("Z-score:", z)
print("P-value:", p)

# Plot
x = np.linspace(-4, 4, 300)
y = norm.pdf(x)
z_crit = norm.ppf(0.975)

plt.plot(x, y)
plt.axvline(z, color='red', label=f'z = {z:.2f}')
plt.axvline(-z_crit, color='gray', linestyle='--')
plt.axvline(z_crit, color='gray', linestyle='--')
plt.fill_between(x, y, where=(x <= -z_crit) | (x >= z_crit), color='red', alpha=0.2)
plt.title("Two-tailed Z-test")
plt.legend()
plt.show()
# Out:
# Z-score: 0.9486832980505139
# P-value: 0.3427817111479112

# %% [markdown]
# ## 5.Create a python function that calculates and visualizes type-1 and type-2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_type1_type2(mu0=100, mu1=105, sigma=10, alpha=0.05, n=30):
    se = sigma / np.sqrt(n)
    z_crit = norm.ppf(1 - alpha/2)

    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 500)
    y0 = norm.pdf(x, mu0, se)  # Null distribution
    y1 = norm.pdf(x, mu1, se)  # Alternative distribution

    plt.plot(x, y0, label="H₀ distribution", color='blue')
    plt.plot(x, y1, label="H₁ distribution", color='green')

    # Critical values
    cv_left = mu0 - z_crit * se
    cv_right = mu0 + z_crit * se

    # Shade Type-I error (α)
    plt.fill_between(x, y0, where=(x < cv_left) | (x > cv_right), color='red', alpha=0.3, label='Type-I Error (α)')

    # Shade Type-II error (β)
    plt.fill_between(x, y1, where=(x > cv_left) & (x < cv_right), color='orange', alpha=0.3, label='Type-II Error (β)')

    plt.legend()
    plt.title("Type-I and Type-II Errors")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Example use
plot_type1_type2()

# %% [markdown]
# ## 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Dummy data: replace with your own
grp1 = np.array([51, 49, 50, 52, 48])
grp2 = np.array([46, 45, 47, 44, 46])

t_stat, p_val = ttest_ind(grp1, grp2, equal_var=False)  # Welch’s t‑test
print(f"T‑stat = {t_stat:.3f}  |  p‑value = {p_val:.4f}")

if p_val < 0.05:
    print("→ Reject H₀ (means differ)")   # interpretation
else:
    print("→ Fail to reject H₀ (no evidence of difference)")
# Out:
# T‑stat = 5.047  |  p‑value = 0.0013
# → Reject H₀ (means differ)

# %% [markdown]
# ## 7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy.stats import ttest_rel

# Paired data (before vs after)
before = np.array([72, 75, 78, 71, 70])
after  = np.array([68, 70, 73, 69, 67])

t_stat, p_val = ttest_rel(before, after)
print(f"Paired T‑stat = {t_stat:.3f} | p = {p_val:.4f}")

# Simple line plot of pairs
plt.plot(before, 'o-', label='Before')
plt.plot(after,  's--', label='After')
plt.title('Paired Sample Comparison')
plt.legend();  plt.show()
# Out:
# Paired T‑stat = 6.517 | p = 0.0029

# %% [markdown]
# ## 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy.stats import norm, ttest_1samp

np.random.seed(0)
sample = np.random.normal(loc=102, scale=15, size=20)  # σ unknown in reality
pop_mean, pop_std = 100, 15                            # assume σ known for Z

# --- Z‑test (σ known) ---
z = (sample.mean() - pop_mean) / (pop_std / np.sqrt(sample.size))
p_z = 2 * (1 - norm.cdf(abs(z)))

# --- One‑sample T‑test (σ unknown) ---
t_stat, p_t = ttest_1samp(sample, pop_mean)

print(f"Z‑test  : z = {z:.3f},  p = {p_z:.4f}")
print(f"T‑test  : t = {t_stat:.3f}, p = {p_t:.4f}")
# Out:
# Z‑test  : z = 3.142,  p = 0.0017
# T‑test  : t = 3.603, p = 0.0019

# %% [markdown]
# ## 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance. give codes for this one by one simple and small.

# %%
import numpy as np
from scipy.stats import t

def ci_mean(data, conf=0.95):
    data = np.asarray(data)
    n, mean, s = len(data), data.mean(), data.std(ddof=1)
    se = s / np.sqrt(n)
    h  = t.ppf((1 + conf) / 2, n-1) * se
    return mean - h, mean + h

# Example
sample = [5.1, 4.9, 5.0, 5.2, 4.8]
print("95% CI:", ci_mean(sample))
# Out:
# 95% CI: (4.803675683852244, 5.196324316147756)

# %% [markdown]
# ## 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import numpy as np
from scipy.stats import t

data = [51, 53, 49, 50, 52]
n = len(data)
mean = np.mean(data)
std = np.std(data, ddof=1)
se = std / np.sqrt(n)
margin = t.ppf(0.975, n-1) * se
print("Margin of Error:", round(margin, 2))
# Out:
# Margin of Error: 1.96

# %% [markdown]
# ## 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
# P(Disease|Positive) = P(Positive|Disease)*P(Disease) / P(Positive)

p_disease = 0.01
p_pos_given_disease = 0.99
p_pos_given_no_disease = 0.05
p_no_disease = 1 - p_disease

# Total probability of positive
p_positive = p_pos_given_disease * p_disease + p_pos_given_no_disease * p_no_disease

# Bayes' rule
posterior = (p_pos_given_disease * p_disease) / p_positive
print("P(Disease | Positive Test):", round(posterior, 3))
# Out:
# P(Disease | Positive Test): 0.167

# %% [markdown]
# ## 12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import scipy.stats as stats

# Contingency table
data = [[20, 15], [30, 35]]
chi2, p, _, _ = stats.chi2_contingency(data)
print("Chi2 =", chi2, "| p-value =", round(p, 4))
# Out:
# Chi2 = 0.7032967032967032 | p-value = 0.4017

# %% [markdown]
# ## 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.

# %%
from scipy.stats import chi2_contingency

# Observed data in a contingency table (e.g., 2x2)
observed = [[30, 10],
            [20, 40]]

# chi2_contingency returns expected frequencies as the 4th output
_, _, _, expected = chi2_contingency(observed)

# Display expected frequencies
print("Expected Frequencies:")
for row in expected:
    print([round(val, 2) for val in row])
# Out:
# Expected Frequencies:
# [20.0, 20.0]
# [30.0, 30.0]

# %% [markdown]
# ## 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
from scipy.stats import chisquare

# Observed and expected frequencies
observed = [18, 22, 20]
expected = [20, 20, 20]  # uniform distribution

# Perform Chi-square goodness-of-fit test
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Display results
print("Chi-square Statistic:", round(chi2_stat, 2))
print("P-value:", round(p_value, 4))

# Interpretation
if p_value < 0.05:
    print("→ Reject H₀ (Observed distribution differs significantly)")
else:
    print("→ Fail to reject H₀ (No significant difference)")
# Out:
# Chi-square Statistic: 0.4
# P-value: 0.8187
# → Fail to reject H₀ (No significant difference)

# %% [markdown]
# ## 15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Set degrees of freedom to compare
dfs = [1, 2, 5, 10]

x = np.linspace(0, 30, 500)

plt.figure(figsize=(8, 5))
for df in dfs:
    plt.plot(x, chi2.pdf(x, df), label=f'df = {df}')

plt.title("Chi-square Distribution")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 16. Implement an F-test using Python to compare the variances of two random samples.

# %%
import numpy as np
from scipy.stats import f

# Two samples
sample1 = [10, 12, 9, 11, 13]
sample2 = [7, 8, 6, 9, 7]

# Calculate variances
var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

# F-statistic
f_stat = var1 / var2
dof1 = len(sample1) - 1
dof2 = len(sample2) - 1

# One-tailed p-value
p_value = 1 - f.cdf(f_stat, dof1, dof2)

print("F-statistic:", round(f_stat, 3))
print("P-value:", round(p_value, 4))

# Interpretation
if p_value < 0.05:
    print("→ Reject H₀ (Variances are significantly different)")
else:
    print("→ Fail to reject H₀ (No significant difference in variances)")
# Out:
# F-statistic: 1.923
# P-value: 0.271
# → Fail to reject H₀ (No significant difference in variances)

# %% [markdown]
# ## 17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.

# %%
from scipy.stats import f_oneway

# Example data for three groups
group1 = [23, 25, 27, 22, 24]
group2 = [31, 33, 30, 29, 32]
group3 = [18, 20, 19, 21, 17]

# Perform one-way ANOVA
f_stat, p_value = f_oneway(group1, group2, group3)

# Display results
print("F-statistic:", round(f_stat, 3))
print("P-value:", round(p_value, 4))

# Interpretation
if p_value < 0.05:
    print("→ Reject H₀: At least one group mean is significantly different.")
else:
    print("→ Fail to reject H₀: No significant difference between group means.")
# Out:
# F-statistic: 62.437
# P-value: 0.0
# → Reject H₀: At least one group mean is significantly different.

# %% [markdown]
# ## 18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

# %%
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# Example groups (you can replace with real data)
group1 = [23, 25, 27, 22, 24]
group2 = [31, 33, 30, 29, 32]
group3 = [18, 20, 19, 21, 17]

# Perform ANOVA
f_stat, p_value = f_oneway(group1, group2, group3)
print("F-statistic:", round(f_stat, 3))
print("P-value:", round(p_value, 4))

# Interpretation
if p_value < 0.05:
    print("→ Reject H₀: Significant difference between group means.")
else:
    print("→ Fail to reject H₀: No significant difference.")

# Plot boxplot
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'])
plt.title("Group Comparison - One-Way ANOVA")
plt.ylabel("Values")
plt.grid(True)
plt.show()
# Out:
# F-statistic: 62.437
# P-value: 0.0
# → Reject H₀: Significant difference between group means.

# %% [markdown]
# ## 19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import shapiro, levene

def check_anova_assumptions(*groups):
    # 1. Normality check (Shapiro-Wilk test)
    for i, group in enumerate(groups, start=1):
        stat, p = shapiro(group)
        print(f"Group {i} Normality p-value: {p:.4f}")
        if p > 0.05:
            print(" → Data looks normal.")
        else:
            print(" → Data may not be normal.")

    # 2. Equal variances (Levene’s test)
    stat, p = levene(*groups)
    print(f"\nLevene’s Test (Equal Variance) p-value: {p:.4f}")
    if p > 0.05:
        print(" → Variances are likely equal.")
    else:
        print(" → Variances may not be equal.")
    
    # 3. Independence - Visual check using line plot (assumes ordered data)
    for i, group in enumerate(groups, start=1):
        plt.plot(group, label=f'Group {i}')
    plt.title("Line Plot to Visually Check Independence")
    plt.xlabel("Index")
    plt.ylabel("Values")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
g1 = [23, 25, 27, 22, 24]
g2 = [31, 33, 30, 29, 32]
g3 = [18, 20, 19, 21, 17]

check_anova_assumptions(g1, g2, g3)
# Out:
# Group 1 Normality p-value: 0.9276
#  → Data looks normal.
# Group 2 Normality p-value: 0.9672
#  → Data looks normal.
# Group 3 Normality p-value: 0.9672
#  → Data looks normal.
#
# Levene’s Test (Equal Variance) p-value: 0.9290
#  → Variances are likely equal.

# %% [markdown]
# ## 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt

# Sample Data: Scores by 'Diet' and 'Exercise'
data = {
    'Score': [80, 82, 84, 78, 76, 75, 90, 88, 85, 70, 72, 73],
    'Diet': ['High', 'High', 'High', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low', 'Low', 'Low'],
    'Exercise': ['Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'Yes', 'Yes']
}

df = pd.DataFrame(data)

# Two-way ANOVA
model = ols('Score ~ C(Diet) + C(Exercise) + C(Diet):C(Exercise)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print("\nTwo-Way ANOVA Results:")
print(anova_table)

# Visualization: Interaction plot
sns.pointplot(x='Diet', y='Score', hue='Exercise', data=df, markers=["o", "s"], linestyles=["-", "--"])
plt.title("Interaction Between Diet and Exercise")
plt.grid(True)
plt.show()
# Out:
# Two-Way ANOVA Results:
#                          sum_sq   df          F    PR(>F)
# C(Diet)              325.513725  1.0  39.110535  0.000245
# C(Exercise)            7.147059  1.0   0.858720  0.381203
# C(Diet):C(Exercise)   37.102941  1.0   4.457925  0.067728
# Residual              66.583333  8.0        NaN       NaN

# %% [markdown]
# ## 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Define degrees of freedom for numerator and denominator
df1_values = [1, 3, 5]
df2 = 10
x = np.linspace(0, 5, 500)

# Plot F-distributions for different df1 values
plt.figure(figsize=(8, 5))
for df1 in df1_values:
    y = f.pdf(x, df1, df2)
    plt.plot(x, y, label=f'df1={df1}, df2={df2}')

plt.title("F-distribution")
plt.xlabel("F value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# Example data: replace with your own groups
group_a = [23, 25, 27, 22, 24]
group_b = [31, 33, 30, 29, 32]
group_c = [18, 20, 19, 21, 17]

# --- One‑way ANOVA ---
f_stat, p_val = f_oneway(group_a, group_b, group_c)
print(f"F = {f_stat:.3f} | p = {p_val:.4f}")

# --- Boxplot visualization ---
data = [group_a, group_b, group_c]
labels = ['A', 'B', 'C']
sns.boxplot(data=data)
plt.xticks(range(len(labels)), labels)
plt.title("Group Comparison (One‑way ANOVA)")
plt.ylabel("Values")
plt.grid(True)
plt.show()
# Out:
# F = 62.437 | p = 0.0000

# %% [markdown]
# ## 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

# %%
import numpy as np
from scipy.stats import ttest_1samp

# 1. Simulate a sample from N(μ=52, σ=10), n = 30
np.random.seed(0)
sample = np.random.normal(loc=52, scale=10, size=30)

# 2. One‑sample t‑test against H₀: μ = 50
t_stat, p_val = ttest_1samp(sample, popmean=50)

print(f"Sample mean = {sample.mean():.2f}")
print(f"T‑statistic = {t_stat:.3f}")
print(f"P‑value     = {p_val:.4f}")

if p_val < 0.05:
    print("→ Reject H₀: mean differs from 50")
else:
    print("→ Fail to reject H₀: no evidence mean ≠ 50")
# Out:
# Sample mean = 56.43
# T‑statistic = 3.200
# P‑value     = 0.0033
# → Reject H₀: mean differs from 50

# %% [markdown]
# ## 24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

# %%
import numpy as np
from scipy.stats import chi2

# Sample data
data = [10, 12, 9, 11, 13, 10, 11, 12]
n = len(data)
sample_var = np.var(data, ddof=1)

# Hypothesized population variance (e.g., H0: σ² = 4)
sigma_squared_0 = 4

# Chi-square statistic
chi2_stat = (n - 1) * sample_var / sigma_squared_0

# Degrees of freedom
df = n - 1

# p-value (two-tailed)
p_value = 2 * min(chi2.cdf(chi2_stat, df), 1 - chi2.cdf(chi2_stat, df))

# Output
print(f"Sample Variance = {round(sample_var, 2)}")
print(f"Chi-square Stat = {round(chi2_stat, 2)}")
print(f"p-value = {round(p_value, 4)}")

# Interpretation
if p_value < 0.05:
    print("→ Reject H₀: Population variance is significantly different from", sigma_squared_0)
else:
    print("→ Fail to reject H₀: No evidence that variance differs from", sigma_squared_0)
# Out:
# Sample Variance = 1.71
# Chi-square Stat = 3.0
# p-value = 0.23
# → Fail to reject H₀: No evidence that variance differs from 4

# %% [markdown]
# ## 25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

# Example:
# Group A: 40 successes out of 100
# Group B: 30 successes out of 90
successes = np.array([40, 30])
samples = np.array([100, 90])

# Perform two-proportion z-test
z_stat, p_value = proportions_ztest(count=successes, nobs=samples)

print(f"Z-statistic = {z_stat:.3f}")
print(f"P-value     = {p_value:.4f}")

# Interpretation
if p_value < 0.05:
    print("→ Reject H₀: Proportions are significantly different")
else:
    print("→ Fail to reject H₀: No significant difference in proportions")
# Out:
# Z-statistic = 0.951
# P-value     = 0.3415
# → Fail to reject H₀: No significant difference in proportions

# %% [markdown]
# ## 26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Two datasets (replace with your own)
a = np.array([10, 12,  9, 11, 13, 14, 12])
b = np.array([ 6,  8,  7,  9,  6,  8,  7])

# --- F‑test (two‑tailed) ---
var_a, var_b = np.var(a, ddof=1), np.var(b, ddof=1)
f_stat       = var_a / var_b if var_a > var_b else var_b / var_a
dof1, dof2   = len(a) - 1, len(b) - 1
p_val        = 2 * (1 - f.cdf(f_stat, dof1, dof2))  # two‑sided

print(f"Variance A = {var_a:.2f}, Variance B = {var_b:.2f}")
print(f"F‑stat     = {f_stat:.3f},  p‑value = {p_val:.4f}")
if p_val < 0.05:
    print("→ Reject H₀: variances differ.")
else:
    print("→ Fail to reject H₀: no evidence of difference.")

# --- Visualize ---
plt.boxplot([a, b], labels=["Dataset A", "Dataset B"])
plt.title(f"F‑test for Variances\nF={f_stat:.2f}, p={p_val:.4f}")
plt.ylabel("Values")
plt.grid(True); plt.show()
# Out:
# Variance A = 2.95, Variance B = 1.24
# F‑stat     = 2.385,  p‑value = 0.3142
# → Fail to reject H₀: no evidence of difference.

# %% [markdown]
# ## 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import numpy as np
from scipy.stats import chisquare

# Simulated observed frequencies (e.g., from a dice roll)
observed = np.array([18, 16, 20, 17, 15, 14])

# Expected frequencies assuming a fair 6-sided die
expected = np.array([100/6] * 6)  # total = 100 rolls

# Perform the Chi-square test
chi2_stat, p_val = chisquare(f_obs=observed, f_exp=expected)

# Display results
print(f"Chi-square Statistic = {chi2_stat:.2f}")
print(f"P-value               = {p_val:.4f}")

# Interpretation
if p_val < 0.05:
    print("→ Reject H₀: Observed distribution differs significantly from expected.")
else:
    print("→ Fail to reject H₀: No significant difference from expected.")
# Out:
# Chi-square Statistic = 1.40
# P-value               = 0.9243
# → Fail to reject H₀: No significant difference from expected.
