# %% [markdown]
# # Regression Assignment

# %% [markdown]
# ## 1.What is simple linear regression?

# %% [markdown]
# ### Simple Linear Regression is a method to predict the value of one variable (Y) using one other variable (X).
#
# ##               Y=mx+c
# 🔍 Example:
# Predicting someone’s weight (Y) based on their height (X).
#
# It fits a straight line through the data to show the relationship.

# %% [markdown]
# ## 2.What are the key assumptions of simple linear regression?

# %% [markdown]
# ✅ 1. Linearity
# - The relationship between X and Y is linear.
# - 📊 The data points should follow a straight-line trend.
#
# ✅ 2. Independence of Errors
# - The residuals (errors) are independent of each other.
# - 📈 No pattern should exist in error terms across observations.
#
# ✅ 3. Homoscedasticity
# - The variance of errors is constant across all levels of X.
# - 📉 Spread of residuals should be uniform.
#
# ✅ 4. Normality of Errors
# - The residuals (errors) should be normally distributed.
# - Useful for valid confidence intervals and hypothesis testing.
#
# ✅ 5. No Multicollinearity (only in multiple regression)
# - ❌ Not a concern in simple regression (since only one predictor).

# %% [markdown]
# ## 3.What does the coefficient m represent in the equation Y=mx+c?

# %% [markdown]
# ### ✅ Slope of the line
# It tells you:
# - How much Y changes for a one-unit increase in X
# - The rate of change between the variables

# %% [markdown]
# ## 4.What does the intercept c represent in the equation Y=mx+c?

# %% [markdown]
# ### ✅ The value of Y when X = 0
# It’s the point where the line crosses the Y-axis.
# - 📊 Example:
#   If
#         Y=2X+5
#    then c=5, meaning:
#     when X=0,Y=5

# %% [markdown]
# ## 5.How do we calculate the slope m in simple linear regression?

# %% [markdown]
# ### The slope m in simple linear regression is calculated using the formula:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread("Screenshot 2025-07-05 113212.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 6.What is tthe purpose of the least square method in simple linera regression?

# %% [markdown]
# ### 📉 In simple terms:
# - Each data point has an actual value (Y) and a predicted value (Ŷ)
# - The error = Y − Ŷ
# - Least squares tries to minimize the total of (Y − Ŷ)² for all points

# %% [markdown]
# ### 🎯 Why?
# - It ensures the line is as close as possible to all the points
# - Makes predictions more accurate and balanced

# %% [markdown]
# ## 7.How is the coeffcient of determination(R)square interpreted in simple linear regression?

# %% [markdown]
# ### The coefficient of determination (R²) in simple linear regression tells you how well the model explains the variation in the dependent variable (Y).

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread("Screenshot 2025-07-05 114011.png")
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 8.What is multiple linear regression?

# %% [markdown]
# ### Multiple Linear Regression is a method used to predict the value of a dependent variable using two or more independent variables.

# %% [markdown]
# ### 📊 Example:
# Predicting someone's salary (Y) based on:
#
# Years of experience (X₁)
#
# Education level (X₂)
#
# Age (X₃)

# %% [markdown]
# ## 9.What is the main difference between simple and multiple linear regression?

# %% [markdown]
# | Feature           | Simple Regression    | Multiple Regression            |
# | ----------------- | -------------------- | ------------------------------ |
# | No. of predictors | 1                    | 2 or more                      |
# | Equation format   | Y = mX + c           | Y = b₀ + b₁X₁ + b₂X₂ + ...     |
# | Use case          | Simple relationships | Complex, multi-factor problems |

# %% [markdown]
# ## 10.What are the key assunptions of multiple linear regression?

# %% [markdown]
# | #   | Assumption                 | Description                                                                              |
# | --- | -------------------------- | ---------------------------------------------------------------------------------------- |
# | 1️⃣ | **Linearity**              | The relationship between the dependent variable and each independent variable is linear. |
# | 2️⃣ | **Independence**           | The residuals (errors) are independent of each other. No autocorrelation.                |
# | 3️⃣ | **Homoscedasticity**       | The residuals have constant variance at all levels of the independent variables.         |
# | 4️⃣ | **No multicollinearity**   | The independent variables are not highly correlated with each other.                     |
# | 5️⃣ | **Normality of residuals** | The residuals are normally distributed (especially important for hypothesis testing).    |
# | 6️⃣ | **No measurement errors**  | The independent variables are measured accurately (not with error).                      |

# %% [markdown]
# ## 11.What is heteroscedasticity, and how does it affect the results of a multiple linear regression model?

# %% [markdown]
# ### ✅ What is Heteroscedasticity?
# Heteroscedasticity means that the variance of the residuals (errors) is not constant across all levels of the independent variables.

# %% [markdown]
# | Problem                        | Impact                                                                                   |
# | ------------------------------ | ---------------------------------------------------------------------------------------- |
# | Biased standard errors         | Leads to **incorrect p-values** and confidence intervals                                 |
# | Inefficient estimates          | Your model might still be unbiased, but **not optimal**                                  |
# | Misleading significance tests  | Some variables may appear **significant when they’re not**, or vice versa                |
# | Violates regression assumption | It breaks the **homoscedasticity assumption**, which is important for hypothesis testing |

# %% [markdown]
# ## 12.How can you improve a multiple linear regression model with high multicollinearity?

# %% [markdown]
# ### Multicollinearity means that two or more independent variables are highly correlated, which makes it hard for the model to estimate their individual effects accurately.

# %% [markdown]
# | Method                                        | Description                                                                                               |
# | --------------------------------------------- | --------------------------------------------------------------------------------------------------------- |
# | **1. Remove correlated predictors**           | Drop one of the highly correlated variables                                                               |
# | **2. Use Principal Component Analysis (PCA)** | Transform correlated features into uncorrelated components                                                |
# | **3. Combine features**                       | Create a new variable (e.g., average or ratio) from correlated ones                                       |
# | **4. Regularization (Ridge/Lasso)**           | Shrinks coefficients and reduces variance; especially **Ridge Regression** is great for multicollinearity |
# | **5. Check Variance Inflation Factor (VIF)**  | Remove variables with **VIF > 5 or 10** to reduce collinearity                                            |
# | **6. Feature selection techniques**           | Use backward elimination or recursive feature elimination (RFE) to keep the most relevant predictors      |

# %% [markdown]
# ## 13.What are some common techniques for transforming categorical variables for use in regression models?

# %% [markdown]
# | Technique                 | Use Case                                                               | Output                                                                    |
# | ------------------------- | ---------------------------------------------------------------------- | ------------------------------------------------------------------------- |
# | **1. One-Hot Encoding**   | For nominal variables (no natural order), e.g. City: Mumbai, Delhi     | Creates a binary column for each category (0/1)                           |
# | **2. Label Encoding**     | For ordinal variables (has order), e.g. Size: Small < Medium < Large   | Assigns each category an integer value (e.g., Small=0, Medium=1, Large=2) |
# | **3. Ordinal Encoding**   | Similar to label encoding but customizable based on ranking            | Good when you want to manually preserve order                             |
# | **4. Binary Encoding**    | For variables with many categories, combines label + binary            | Reduces dimensionality compared to one-hot                                |
# | **5. Frequency Encoding** | Replace category with frequency/count of its occurrence                | Useful when frequency carries meaning                                     |
# | **6. Target Encoding**    | Replace category with average target value (used in tree-based models) | Risk of overfitting – use with cross-validation                           |

# %% [markdown]
# ## 14.What is the role of interaction terms in multiple linear regression?

# %% [markdown]
# ### Interaction terms are used in multiple linear regression to model situations where the effect of one independent variable depends on the value of another.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as implt

img=implt.imread("Screenshot 2025-07-11 002439.png")
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 15.How can the interpretation of intercept differ between simple and multiple linear regression?

# %% [markdown]
# ### 🔹 In Simple Linear Regression:
# The intercept (c) represents the predicted value of the dependent variable (Y) when the independent variable (X) is 0.
#       y=mx+c
# 📘 Example:
# If you're predicting salary based on years of experience:
#
# Salary=5000×Experience+20000
# The intercept = 20,000, which means:
#
# When experience = 0, predicted salary is ₹20,000.

# %% [markdown]
# ### 🔹 In Multiple Linear Regression:
# The intercept (b₀) is the predicted value of Y when all independent variables (X₁, X₂, ..., Xₙ) are 0.

# %% [markdown]
# ### 📘 Example:
# If you're predicting house price based on size and location:
#
# Price=5000+300×Size+10000×CityRank
# Intercept = ₹5,000, meaning:
#
# When size = 0 and city rank = 0, the predicted price is ₹5,000.

# %% [markdown]
# ## 16.What is the significance of the slope in regression analysis, and how does it affect prediction?

# %% [markdown]
# ### The slope (also called coefficient) in regression tells us:
# How much the dependent variable (Y) changes for a 1-unit change in an independent variable (X), assuming all other variables remain constant.
#
# ### 📘 Example:
#
# Salary=5000×Experience+20000
# Slope = 5000 → every 1 extra year of experience increases salary by ₹5,000.

# %% [markdown]
# 📌 In prediction:
# - Slopes directly determine the forecasted value.
# - Incorrect slope → poor prediction.
# - Let me know if you'd like a visual example with sample data!

# %% [markdown]
# ## 17.How does the intercept in a regression model provide context for the relationship between variables?

# %% [markdown]
# ### 📌What is the inytercept?
#   Y=mX+c
# here,
# - Y is the predicted(dependent) variable
# - X is the input(independent) variable
# - m is the slope(effect of X on Y)
# - c is the intercapt
#
# ### 🧠 Meaning of the Intercept
# - The intercept (c) is the value of Y when X = 0.

# %% [markdown]
# ### ✅ Example
# imagine a regression model predicting salary based on years of experience:
#     salary=30,000+5,000*(Years of experience)
# - intercept(30,000): Even if a person has 0 years of experience, the model estimates
#    their salary as ₹30,000.
# - slope(5,000): for every additional year of experience,salary increases by₹5,000.
#
# ### so the intercept gives context to the slope, anchoring the relationship

# %% [markdown]
# ## 18.What are the limitations of using R(square) as a sole measure of model      performance?

# %% [markdown]
# ### 📊 What is R²?
# -  R² measures the proportion of variance in the dependent variable(Y) that is explained by the independent variable(X).
#
#      R²=1-(SSR/SST)
#
# ### ⚠️ Limitations of R²
#
# 1. ❌ High R² Doesn’t Mean Good Model
# - A high R² might occur even if the model is poor (especially with non-linear    patterns, overfitting, or irrelevant variables).
#
# 2. 📈 R² Always Increases With More Variables
# - Adding more predictors will never decrease R², even if they’re useless.
# - This can lead to overfitting — the model fits the training data well but
#   performs poorly on new data.
#
# 3. 🔮 No Insight on Causality
# - R² tells you how well the model fits, not why the variables are related.
# - A high R² doesn't imply X causes Y.

# %% [markdown]
# ## 19.how would you interpret a large standard error for a regression    coefficient?

# %% [markdown]
# ### 📏 What is Standard Error (SE) of a Coefficient?
# - It tells you how much the estimated coefficient is expected to vary from sample to sample.

# %% [markdown]
# ###📉 Interpretation of a Large Standard Error
#    If a regression coefficient has a large standard error, it means:
#
# | 🔍 Observation                              | 📌 Interpretation                                                                    |
# | ------------------------------------------- | ------------------------------------------------------------------------------------ |
# | The coefficient is **not precise**          | It could change a lot with different data samples                                    |
# | It may be **statistically insignificant**   | Even if the coefficient value is large, it might not be reliably different from zero |
# | The **confidence interval will be wide**    | So you can't say with certainty what the true value is                               |
# | The predictor may be **weak or irrelevant** | It’s not helping explain the variation in Y clearly                                  |

# %% [markdown]
# ## 20.How can heteroscadisticity be identified  in residual plots, and why is it important to address it?

# %% [markdown]
# ### ✅ What is Heteroscedasticity?

# %% [markdown]
# ### The variance of residuals (errors) is not constant across all levels of the independent variable(s).

# %% [markdown]
# ### 🔍 How to Identify Heteroscedasticity in Residual Plots
#
# ### 📈 Using a Residual vs Fitted Plot:
# In this plot:
# - X-axis: Predicted values (fitted values)
# - Y-axis: Residuals (errors = actual − predicted)
#
# ### 🧠 Why It’s Important to Address
#
# | Problem                             | Impact                                                         |
# | ----------------------------------- | -------------------------------------------------------------- |
# | 📉 **Biased standard errors**       | Leads to **wrong p-values and confidence intervals**           |
# | ❌ **Misleading significance tests** | You may falsely conclude a variable is significant or not      |
# | 📊 **Poor prediction intervals**    | Model may under- or overestimate uncertainty in predictions    |
# | ⚠️ **Model instability**            | High variance in some regions reduces reliability of the model |

# %% [markdown]
# ## 21.What does it mean if a multiple linear regression model has a high R² but low asjusted R²?

# %% [markdown]
# - R² (Coefficient of Determination):
#   Measures how much of the variance in the dependent variable is explained by the independent variables.
# - Adjusted R²:
#   Similar to R² but penalizes for adding unnecessary predictors. It adjusts for the number of predictors and sample size.

# %% [markdown]
# - 📌 If R² is high but Adjusted R² is low, it means:
# - Your model explains a lot of variance on paper, but many predictors don’t add real explanatory power.
# - Additional predictors are inflating R² artificially because R² always increases or stays the same when you add variables, even irrelevant ones.
# - Adjusted R² dropped because those extra predictors do not improve the model enough to justify their inclusion.

# %% [markdown]
# ## 22.Why is it important to scale variables in multiple linear regression?

# %% [markdown]
# | Benefit          | Why It Matters                      |
# | ---------------- | ----------------------------------- |
# | Stability        | Avoids numeric overflow & errors    |
# | Interpretability | Coefficients become comparable      |
# | Regularization   | Prevents biased penalty application |
# | Optimization     | Improves convergence speed          |

# %% [markdown]
# ## 23.What is polynomial regression?

# %% [markdown]
# ### ✅ Polynomial Regression — Explained Simply
# Polynomial Regression is a type of regression that models the relationship between the independent variable(s) X and the dependent variable Y as an nth-degree polynomial

# %% [markdown]
# ## 24.How does polynomial regression differ linear regression?

# %% [markdown]
# ### Linear Regression assumes a straight-line relationship between the independent variable(s) and the dependent variable
#
# ### Polynomial Regression models a curved relationship by including higher-order powers of the predictor:

# %% [markdown]
# ### Complexity
# - Linear Regression: Only one slope coefficient for each predictor.
# - Polynomial Regression: Multiple coefficients for each power of the variable (adds flexibility but increases complexity).

# %% [markdown]
# ###  When to Use
# - Linear Regression: When the data shows a straight-line trend.
# - Polynomial Regression: When the relationship is non-linear but still smooth (e.g., U-shaped or curved patterns).

# %% [markdown]
# ## 25.When is polynomial regression used?

# %% [markdown]
# ### ✅ Common Use Cases
# - 1.Curved Trends in Data
#    - When a straight line (linear regression) does not fit the data well.
#    - Example: Growth patterns, temperature trends, or sales data with seasonal effects.
#
# - 2.U-shaped or Inverted U-shaped Patterns
#     - Example: Advertising spend vs. sales (diminishing returns).
#
#
# - 3.Modeling Complex Relationships
#    - Where adding higher-order terms improves prediction accuracy without overfitting too much.

# %% [markdown]
# ## 26.What is the general equation for polynomial regression?

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mgimg
img=mgimg.imread("Screenshot 2025-07-16 233301.png")
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 27.Can polynomial regression be applied to multiple variables?

# %% [markdown]
# ### ✅ Yes, polynomial regression can be applied to multiple variables.
# This is known as Multivariate Polynomial Regression.
#
# 🔍 How It Works
# Instead of having one predictor x, we include multiple predictors x1,x2,...,xk and their powers.

# %% [markdown]
# ## 28.What are the limitations of polynomial regression?

# %% [markdown]
# ### ✅ 1. Risk of Overfitting
# - Higher-degree polynomials can fit the training data too well, capturing noise instead of the true trend.
# - Leads to poor generalization on new data.
#
# ✅ 2. Sensitive to Outliers
# - Outliers can heavily distort the curve because polynomial terms amplify their effect.
#
# ✅ 3. Extrapolation Issues
# - Predictions outside the range of training data can become wildly inaccurate because the curve can rise or fall sharply.
#
# ✅ 4. High Complexity
# - As the degree of the polynomial increases:
#   - The model becomes harder to interpret.
#   - Computational cost rises.
#   - Feature space explodes (especially with multiple variables).
#
# ✅ 5. Multicollinearity
# - Polynomial terms (e.g., x,x2,x3) are often highly correlated, which can inflate variance in coefficient estimates.
#
# ✅ 6. Assumes Global Relationship
# - A single polynomial equation tries to fit the entire dataset, which may not capture local variations well.
#
# ✅ 7. Not Always the Best for Non-Linear Data
# - Complex non-linear patterns are sometimes better handled by:
#   - Spline Regression
#   - Decision Trees
#   - Neural Networks

# %% [markdown]
# ## 29.What  methods can be used to evaluate model fit when selecting the drgree of a polynomial?

# %% [markdown]
# | Method           | Detects                    |
# | ---------------- | -------------------------- |
# | Residual Plots   | Under/Overfitting visually |
# | Cross-Validation | Best generalization        |
# | Adjusted R²      | Model complexity penalty   |
# | AIC/BIC          | Penalized likelihood       |
# | Visualization    | Human intuition            |

# %% [markdown]
# ## 30.Why is visualization important in polynomial regression?

# %% [markdown]
# ### ✅ Why Visualization Matters
# 1. Understanding the Relationship
# - Polynomial regression introduces curves into the model.
# - Visualizing the fitted curve against the actual data points shows if the model captures the trend or misses important patterns.
#
# 2. Detecting Overfitting or Underfitting
# - Underfitting: The curve is too simple and misses variations → visible as large gaps.
# - Overfitting: The curve oscillates too much, closely following noise → visible as unnecessary wiggles.
#
# 3. Choosing the Right Polynomial Degree
# - Visualization makes it easy to compare:
# - Linear fit vs Quadratic fit vs Cubic fit, etc.
# - Helps pick a degree that balances accuracy and simplicity.
#
# 4. Communicating Results
# - Graphs provide an intuitive way for others (non-technical stakeholders) to    - understand model performance and patterns.

# %% [markdown]
# ## 31.How is polynomial regression implement in python?

# %% [markdown]
# ### ✅ Step 1: Import Libraries

# %%
import numpy as np
import matpplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynoomialFeatures
from sklearn.metrics import mean_squared_errror

# %% [markdown]
# ### ✅ Step 2: Create Sample Data

# %%
# Generate some non-linear data
X = np.linspace(0, 10, 50).reshape(-1, 1)
y = 3 + 2*X + 1*X**2 + np.random.randn(50, 1)*5  # Quadratic relationship

# %% [markdown]
# ### ✅ Step 3: Transform Features to Polynomial

# %%
# Create polynomial features of degree 2
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %% [markdown]
# ### ✅ Step 4: Fit Polynomial Regression Model

# %%
model = LinearRegression()
model.fit(X_poly, y)

# %% [markdown]
# ### ✅ Step 5: Predict

# %%
y_pred = model.predict(X_poly)
